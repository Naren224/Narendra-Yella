# %%
import pandas as pd

# %%
chipo=pd.read_csv(r"C:\Users\NARENDRA\Downloads\File\File\chipotle_Ex2.csv")

# %%
chipo.head(10)
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
# 5           5         3         1                           Chicken Bowl
# 6           6         3         1                          Side of Chips
# 7           7         4         1                          Steak Burrito
# 8           8         4         1                       Steak Soft Tacos
# 9           9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# ...

# %%
#What is the number of observations in the dataset?

chipo.shape[0]
# Out:
# 4622

# %%
# Question 6: Find the number of columns in the dataset

print(chipo.shape[1])
# Out:
# 6

# %%
# Question 7: Display all column names

print(chipo.columns)
# Out:
# Index(['Unnamed: 0', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# Question 8: Display the index of the dataset

print(chipo.index)
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# Question 8: Display the index of the dataset

print(chipo.index)
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
# Question 9: Find the most ordered item

most_ordered = chipo.groupby("item_name")["quantity"].sum()
print(most_ordered.sort_values(ascending=False).head(1))
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %%
# Question 10: Find how many quantities of the most ordered item were ordered

most_ordered = chipo.groupby("item_name")["quantity"].sum()
print(most_ordered.sort_values(ascending=False).head(1))
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %%
# Question 11: Find the most ordered item in choice_description

choice_item = chipo.groupby("choice_description")["quantity"].sum()

print(choice_item.sort_values(ascending=False).head(1))
# Out:
# choice_description
# [Diet Coke]    159
# Name: quantity, dtype: int64

# %%
# Question 12: Calculate total quantity ordered

print(chipo["quantity"].sum())
# Out:
# 4972

# %%
# Question 13a: Check the data type of item_price

print(chipo["item_price"].dtype)
# Out:
# object

# %%
# Question 13c: Verify the new datatype of item_price

print(chipo["item_price"].dtype)
# Out:
# float64

# %%
# Question 14: Calculate total revenue

revenue = (chipo["quantity"] * chipo["item_price"]).sum()

print("Revenue =", revenue)
# Out:
# Revenue = 39237.02

# %%
# Question 15: Find total number of orders

print(chipo["order_id"].nunique())
# Out:
# 1834

# %%
# Question 16: Calculate average revenue per order

revenue = (chipo["quantity"] * chipo["item_price"]).sum()

orders = chipo["order_id"].nunique()

avg_revenue = revenue / orders

print(avg_revenue)
# Out:
# 21.39423118865867

# %%
# Question 17: Find the number of different items sold

print(chipo["item_name"].nunique())
# Out:
# 50
