# %%
a=10
print(a)
# Out:
# 10

# %%
a=20
print(a)
# Out:
# 20

# %%
# Program by Naren - 18 Sept 2025
a="Hello Eric, would you like to learn some Python today?" 
print(a)
# Out:
# Hello Eric, would you like to learn some Python today?

# %%
# Program by Naren - 18 Sept 2025
# This program prints a famous quote from Albert Einstein.

a= 'Albert Einstein once said, “A person who never made a mistake never tried anything new."'
print(a)
# Out:
# Albert Einstein once said, “A person who never made a mistake never tried anything new."

# %%
famous_person="Albert Einstein"
message=' once said, "A person who never made a mistake never tried anything new."'
print(famous_person,message)
# Out:
# Albert Einstein  once said, "A person who never made a mistake never tried anything new."

# %%
print(5+3)
# Out:
# 8

# %%
print(10-2)
# Out:
# 8

# %%
print(4*2)
# Out:
# 8

# %%
print(80/10)
# Out:
# 8.0

# %%
Love=143
print(Love)
# Out:
# 143

# %%
name=("Rajesh","Prasad","Narendra","Priya","Ganesh")
print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
# Out:
# Rajesh
# Prasad
# Narendra
# Priya
# Ganesh

# %%
print("Hello",name[0],",How are you?")
print("Hello",name[1],",How are you?")
print("Hello",name[2],",How are you?")
print("Hello",name[3],",How are you?")
print("Hello",name[4],",How are you?")
# Out:
# Hello Rajesh ,How are you?
# Hello Prasad ,How are you?
# Hello Narendra ,How are you?
# Hello Priya ,How are you?
# Hello Ganesh ,How are you?

# %%
vehicle=("BMW","Benz","Lamborgini","Ferrari")
print("I would like to have",vehicle[2],".")
# Out:
# I would like to have Lamborgini .
